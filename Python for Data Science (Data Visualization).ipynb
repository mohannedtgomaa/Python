# %% [markdown]
# Import Needed Packages

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# Setting Working Directory

# %%
import os

# %%
print("Current Working Directory " , os.getcwd()) #checking for current WD

if os.path.exists ('D:UT Autin\Python for DS'):
    os.chdir('D:UT Autin\Python for DS')
    print("Working Directory Changed")  
else:
    print("Can't change the Current Working Directory")  #Changing WD, with existance check in place
# Out:
# Current Working Directory  D:\UT Autin\Python for DS
# Can't change the Current Working Directory

# %% [markdown]
# Import Data

# %%
auto = pd.read_csv('Automobile (1)-1.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# Building Distribution plot. along with density curve

# %%
sns.distplot(auto['normalized_losses'])

# %%
sns.distplot(auto['engine_size'])

# %%
sns.distplot(auto['city_mpg'])

# %% [markdown]
# Building a Histogram

# %%
sns.distplot(auto['city_mpg'], kde = False, rug = True)

# %%
sns.distplot(auto['normalized_losses'], kde = False, rug = True)

# %%
#Note that rug in the chart show the denisty of o signle obs at a certain value

# %% [markdown]
# Bivariate Vis

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'])

# %% [markdown]
# The graph shows a high coreelation  betwen the two varibales, with 0.82. There few visable outlier in the top right side of the chart

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'], kind ='hex')

# %% [markdown]
# The drakeer the color the more obs at this point.

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='reg')

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='kde')

# %% [markdown]
# Multivariate Vis

# %%
sns.pairplot(auto[['normalized_losses','engine_size','horsepower']])

# %% [markdown]
# Plotting Cat. Variable

# %%
sns.stripplot(auto['fuel_type'],auto['horsepower'],jitter = True)

# %% [markdown]
# There lots of cars with low horse power, one outerlier on top. There are less diesel cars than gas ones.

# %%
sns.swarmplot(auto['fuel_type'],auto['horsepower'])

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower'])

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower'], hue = auto['fuel_type'])

# %%
sns.barplot(auto['body_style'],auto['horsepower'])

# %%
sns.barplot(auto['body_style'],auto['horsepower'], hue = auto['engine_location'])

# %%
sns.countplot(auto['body_style'])

# %%
sns.countplot(auto['body_style'], hue=auto['engine_location'])

# %%
sns.pointplot(auto['fuel_system'],auto['horsepower'])

# %%
sns.pointplot(auto['fuel_system'],auto['horsepower'], hue = auto['fuel_system'])

# %%
sns.pointplot(auto['fuel_system'],auto['horsepower'], hue = auto['number_of_cylinders'])

# %%
sns.pointplot(auto['fuel_system'],auto['horsepower'], hue = auto['number_of_doors'])

# %%
sns.factorplot(x= 'fuel_type',
               y = "horsepower",
               col = 'engine_location',
               data = auto,
               kind = 'swarm')

# %%
sns.factorplot(x= 'fuel_type',
               y = "horsepower",
               col = 'engine_location',
               data = auto,
               kind = 'point')

# %%
sns.factorplot(x= 'fuel_type',
               col = 'engine_location',
               data = auto,
               kind = 'count')

# %%
sns.factorplot(x= 'fuel_type',
               y = "horsepower",
               col = 'engine_location',
               data = auto,
               kind = 'box')

# %%
sns.factorplot(x= 'fuel_type',
               y = "horsepower",
               col = 'engine_location',
               data = auto,
               kind = 'violin')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.lmplot(x ="horsepower", y = "peak_rpm", data= auto)

# %%
sns.lmplot(x ="horsepower", y = "peak_rpm", data= auto , hue = "fuel_type")

# %% [markdown]
# Negative realtion for diesel cars.
